# %%
#load unique_time_blocks.npy
import numpy as np
import scipy

data = np.load('unique_time_blocks.npy')

# %%
print(data)
# Out:
# [  95   96   97  259  260  261  262  263  264  265  266  267  274  275
#   276  277  278  279  280  281  282  283  284  370  371  372  373  374
#   400  404  405  406  456  457  458  476  477  478  479  480  481  482
#   483  484  485  486  487  488  489  506  507  508  509  515  516  517
#   518  519  520  521  750  751  752  753  754  755  897  898  899  900
#   901  905  906  907  961  962  963  964  965  966 1002 1003 1004 1005
#  1006 1021 1022 1023 1024 1025 1026 1027 1028 1029 1030 1031 1040 1041
#  1042 1043 1044 1045 1046 1051 1052 1053 1054 1055 1056 1057 1058 1059
#  1060 1061 1062 1063 1064 1065 1066 1067 1068 1072 1073 1074 1075 1076
#  1077 1078 1079 1080 1081 1082 1083 1084 1085 1086 1087 1088 1089 1090
#  1091 1092 1096 1097 1098 1103 1104 1105 1106 1121 1122 1133 1134 1135
#  1157 1158 1159 1160 1161 1162 1163 1165 1166 1167 1168 1169 1170 1171
#  1172 1177 1178 1179 1180 1181 1182 1227 1228 1229 1230 1231 1232 1233
# ...

# %%
data.shape
# Out:
# (223,)

# %%
indices = np.load('indices.npy')

# %%
len(indices)
# Out:
# 803

# %%
indices
# Out:
# array([ 340,  341,  342,  343,  344,  345,  346,  347,  348,  349,  350,
#         998,  999, 1000, 1001, 1002, 1003, 1004, 1005, 1007, 1008, 1009,
#        1010, 1011, 1012, 1013, 1014, 1015, 1016, 1017, 1018, 1019, 1020,
#        1021, 1022, 1023, 1024, 1025, 1026, 1027, 1028, 1029, 1030, 1057,
#        1058, 1059, 1060, 1061, 1062, 1063, 1064, 1065, 1066, 1067, 1068,
#        1069, 1070, 1071, 1072, 1073, 1074, 1075, 1076, 1077, 1078, 1079,
#        1081, 1082, 1083, 1084, 1085, 1086, 1087, 1088, 1089, 1090, 1091,
#        1092, 1093, 1094, 1095, 1096, 1097, 1098, 1386, 1387, 1388, 1389,
#        1390, 1391, 1392, 1393, 1394, 1395, 1396, 1397, 1398, 1399, 1504,
#        1505, 1506, 1522, 1523, 1524, 1525, 1526, 1527, 1528, 1529, 1728,
#        1729, 1730, 1731, 1732, 1733, 1734, 1735, 1807, 1808, 1809, 1810,
#        1811, 1812, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820, 1821,
#        1822, 1823, 1824, 1825, 1826, 1827, 1828, 1829, 1830, 1831, 1832,
# ...

# %%
len(indices)
# Out:
# 803

# %%
words = scipy.io.loadmat('original/subject_1.mat')

# %%
words = [i[0][0][0][0] for i in words['words'][0]]

for i in indices:
    print(words[i])
# Out:
# Hermione
# Granger
# was
# almost
# as
# nervous
# about
# flying
# as
# Neville
# was.
# On
# my
# whistle
# --
# three
# --
# two
# —"
# But
# Neville,
# nervous
# and
# jumpy
# and
# frightened
# of
# being
# left
# on
# the
# ground,
# pushed
# off
# hard
# before
# the
# whistle
# had
# touched
# Madam
# Hooch's
# lips.
# Harry
# saw
# his
# scared
# white
# face
# look
# down
# at
# the
# ground
# falling
# away,
# saw
# him
# gasp,
# slip
# sideways
# off
# the
# broom
# and
# --
# WHAM
# --
# a
# thud
# and
# a
# nasty
# crack
# and
# Neville
# lay
# facedown
# on
# the
# grass
# in
# a
# heap.
# "Madam
# Hooch
# told
# us
# not
# to
# move
# --
# you'll
# get
# us
# all
# into
# trouble."
# Malfoy
# looked
# stunned.
# said
# Malfoy,
# trying
# to
# sneer,
# but
# looking
# worried.
# His
# heart
# sank
# faster
# than
# he'd
# just
# dived.
# Harry
# caught
# sight
# of
# Malfoy,
# Crabbe,
# and
# Goyle's
# triumphant
# faces
# as
# he
# left,
# walking
# numbly
# in
# ...

# %%
words['words'][0][1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 words['words'][0][1]
#
# TypeError: list indices must be integers or slices, not str

# %%
words['words'][0][0]
# Out:
# (array([[array(['Harry'], dtype='<U5')]], dtype=object), array([[20]], dtype=uint8), array([[0.5]]))

# %%
mappings = np.load('time_block_map.npy', allow_pickle=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 mappings[0]
#
# IndexError: too many indices for array: array is 0-dimensional, but 1 were indexed
